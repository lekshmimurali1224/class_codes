# %% [markdown]
# <a href="https://colab.research.google.com/github/lekshmimurali1224/class_codes/blob/main/Multiple_Linear_Regression_Nov17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#from statsmodels.tsa.seasonal import seasonal_decompose
#from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import warnings
warnings.filterwarnings('ignore')

# %%
#Import the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1215eb1c-7716-4bf3-972f-259a5d91e586" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1215eb1c-7716-4bf3-972f-259a5d91e586">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Getting the data intodataframe.
df = pd.read_csv('Cars.csv', index_col=0)
df.head()
# Out:
#           MPG  VOL          SP         WT
# HP
# 49  53.700681   89  104.185353  28.762059
# 55  50.013401   92  105.461264  30.466833
# 55  50.013401   92  105.461264  30.193597
# 70  45.696322   92  113.461264  30.632114
# 53  50.504232   92  104.461264  29.889149

# %%
df.isnull()
# Out:
#        MPG    VOL     SP     WT
# HP
# 49   False  False  False  False
# 55   False  False  False  False
# 55   False  False  False  False
# 70   False  False  False  False
# 53   False  False  False  False
# ..     ...    ...    ...    ...
# 322  False  False  False  False
# 238  False  False  False  False
# 263  False  False  False  False
# 295  False  False  False  False
# 236  False  False  False  False
#
# [81 rows x 4 columns]

# %%
#Finding the correlation.
df.corr()
# Out:
#           MPG       VOL        SP        WT
# MPG  1.000000 -0.529057 -0.687125 -0.526759
# VOL -0.529057  1.000000  0.102170  0.999203
# SP  -0.687125  0.102170  1.000000  0.102439
# WT  -0.526759  0.999203  0.102439  1.000000

# %%
#Pair plot drawing
sns.set_style(style='darkgrid')
sns.pairplot(df)

# %%
#Homework ;Derive the conclusion from the plot.

# %%
print(df.columns)
# Out:
# Index(['MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
#Prepare the model
model = smf.ols('MPG~WT+VOL+SP', data=df).fit()

# %%
#Coefficients
model.params
# Out:
# Intercept    104.470477
# WT             1.606615
# VOL           -0.729199
# SP            -0.412236
# dtype: float64

# %%
#Homework : Write the quation from the parameters.

# %%
#p values
print(model.tvalues, '\n\n', model.pvalues)
# Out:
# Intercept    18.552999
# WT            0.826188
# VOL          -1.116129
# SP           -9.999396
# dtype: float64
#
#  Intercept    3.858730e-30
# WT           4.112502e-01
# VOL          2.678381e-01
# SP           1.449470e-15
# dtype: float64

# %%
#Interpret the tvalues and give the conclusion.

# %%
#R Squared values
print(model.rsquared, '\n\n', model.rsquared_adj)
# Out:
# 0.6876760478006347
#
#  0.6755075821305296
